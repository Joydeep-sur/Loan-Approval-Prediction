# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('loan_approval_dataset.csv')
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
#clean column names
df.columns= df.columns.str.strip()
#clean object
for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   object
#  3   self_employed             4269 non-null   object
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
sns.countplot(x='education', hue='loan_status', data=df,)
plt.show()

# %%
sns.countplot(x='self_employed', hue='loan_status', data=df,)
plt.show()

# %%
#count of graduate person
count_graduate= len(df[df['education']=="Graduate"])
count_graduate
# Out:
# 2144

# %%
#count of non_graduate person
count_Not_graduate= len(df[df['education']=="Not Graduate"])
count_Not_graduate
# Out:
# 2125

# %%
Total_count= count_graduate + count_Not_graduate
Total_count
# Out:
# 4269

# %%
print("percentage of graduate peoples are {:.2f}%".format((count_graduate/len(df))*100))
print("percentage of non_graduate peoples are {:.2f}%".format((count_Not_graduate/len(df))*100))
# Out:
# percentage of graduate peoples are 50.22%
# percentage of non_graduate peoples are 49.78%

# %%
#count of self employed

count_self_employed= len(df[df['self_employed']=="Yes"])
count_self_employed
# Out:
# 2150

# %%
#count of employed
count_employed= len(df[df['self_employed']=="No"])
count_employed
# Out:
# 2119

# %%
# percentage of elf_employed

print ("percentage of self employed are {:.2f}% ".format((count_self_employed/len(df))*100))
print ("percentage of employed are {:.2f}% ".format((count_employed/len(df))*100))
# Out:
# percentage of self employed are 50.36%
# percentage of employed are 49.64%

# %%
plt.figure(figsize = (12,8))
plt.subplot(2,2,1)
sns.countplot(x="self_employed", data = df)
plt.subplot(2,2,2)
sns.countplot (x="loan_term", data = df)
plt.subplot(2,2,3)
sns.histplot(x="income_annum", data =df)
plt.subplot(2,2,4)
sns.histplot(x="loan_amount", data =df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#byvariate analysis
sns.scatterplot(x= "income_annum", y= "loan_amount", data = df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Num_col = [
    'income_annum',
    'loan_amount',
    'loan_term',
    'cibil_score',
    'residential_assets_value',
    'commercial_assets_value',
    'luxury_assets_value',
    'bank_asset_value'
]
Num_col
# Out:
# ['income_annum',
#  'loan_amount',
#  'loan_term',
#  'cibil_score',
#  'residential_assets_value',
#  'commercial_assets_value',
#  'luxury_assets_value',
#  'bank_asset_value']

# %%
#multivariate analysis
sns.heatmap(data = df[Num_col].corr(),annot=True,cmap="plasma")
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 #multivariate analysis
# ----> 2 sns.heatmap(data = df[Num_col].corr(),annot=True,cmap="plasma")
#       3 plt.show
#
# NameError: name 'Num_col' is not defined

# %%
df.isnull().sum()
# Out:
# loan_id                     0
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
model_data = df.copy()
model_data
# Out:
#       loan_id  no_of_dependents     education self_employed  income_annum  \
# 0           1                 2      Graduate            No       9600000
# 1           2                 0  Not Graduate           Yes       4100000
# 2           3                 3      Graduate            No       9100000
# 3           4                 3      Graduate            No       8200000
# 4           5                 5  Not Graduate           Yes       9800000
# ...       ...               ...           ...           ...           ...
# 4264     4265                 5      Graduate           Yes       1000000
# 4265     4266                 0  Not Graduate           Yes       3300000
# 4266     4267                 2  Not Graduate            No       6500000
# 4267     4268                 1  Not Graduate            No       4100000
# 4268     4269                 1      Graduate            No       9200000
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# ...

# %%
model_data = model_data.drop(['loan_id'], axis = 1)
model_data
# Out:
#       no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                    2      Graduate            No       9600000     29900000
# 1                    0  Not Graduate           Yes       4100000     12200000
# 2                    3      Graduate            No       9100000     29700000
# 3                    3      Graduate            No       8200000     30700000
# 4                    5  Not Graduate           Yes       9800000     24200000
# ...                ...           ...           ...           ...          ...
# 4264                 5      Graduate           Yes       1000000      2300000
# 4265                 0  Not Graduate           Yes       3300000     11300000
# 4266                 2  Not Graduate            No       6500000     23900000
# 4267                 1  Not Graduate            No       4100000     12800000
# 4268                 1      Graduate            No       9200000     29700000
#
# ...

# %%
model_data= pd.get_dummies(model_data,dtype=int)
model_data
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       9600000     29900000         12          778
# 1                    0       4100000     12200000          8          417
# 2                    3       9100000     29700000         20          506
# 3                    3       8200000     30700000          8          467
# 4                    5       9800000     24200000         20          382
# ...                ...           ...          ...        ...          ...
# 4264                 5       1000000      2300000         12          317
# 4265                 0       3300000     11300000         20          559
# 4266                 2       6500000     23900000         18          457
# 4267                 1       4100000     12800000          8          780
# 4268                 1       9200000     29700000         10          607
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# ...

# %%
#feature engineering
model_data = model_data.drop(['loan_status_Rejected'], axis=1)

# %%
model_data= model_data.rename(columns = {'loan_status_Approved': 'Loan_status'})
model_data
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       9600000     29900000         12          778
# 1                    0       4100000     12200000          8          417
# 2                    3       9100000     29700000         20          506
# 3                    3       8200000     30700000          8          467
# 4                    5       9800000     24200000         20          382
# ...                ...           ...          ...        ...          ...
# 4264                 5       1000000      2300000         12          317
# 4265                 0       3300000     11300000         20          559
# 4266                 2       6500000     23900000         18          457
# 4267                 1       4100000     12800000          8          780
# 4268                 1       9200000     29700000         10          607
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# ...

# %%
#feature seperation
x= model_data.drop(['Loan_status'],axis=1)
y= model_data ['Loan_status']

# %%
#smote
# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE
x,y= SMOTE().fit_resample(x,y)
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sns.countplot (y=y, data = model_data)
# Out:
# <Axes: xlabel='count', ylabel='Loan_status'>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
x=MinMaxScaler().fit_transform(x)

x
# Out:
# array([[0.4       , 0.96907216, 0.75510204, ..., 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.40206186, 0.30357143, ..., 1.        , 0.        ,
#         1.        ],
#        [0.6       , 0.91752577, 0.75      , ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.2       , 0.10309278, 0.11093431, ..., 1.        , 0.        ,
#         0.        ],
#        [0.6       , 0.68893814, 0.60759574, ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.84269474, 0.69414102, ..., 0.        , 0.        ,
#         1.        ]], shape=(5312, 13))

# %%
#train_test_split
x_train, x_test, y_train, y_test = train_test_split (x,y, test_size=0.2)

# %%
#modelling

classifier= LogisticRegression(solver = "saga", max_iter = 500, random_state =1)
classifier.fit(x_train,y_train)
y_pred = classifier.predict(x_test)
print (classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       525
#            1       0.95      0.93      0.94       538
#
#     accuracy                           0.94      1063
#    macro avg       0.94      0.94      0.94      1063
# weighted avg       0.94      0.94      0.94      1063

# %%
#our model is 94% accurate
